# %% [markdown]
# # Libraries

# %%
import os
from io import StringIO 
import pandas as pd
from urllib import request
from bs4 import BeautifulSoup
import re
import plotly.plotly as py
import plotly.graph_objs as go
import requests
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import nltk
from nltk import word_tokenize, everygrams
from nltk.util import ngrams
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Obtain data

# %% [markdown]
# ## Function Definitions

# %%
def single_read_in_text(file_path,file_name):
    '''
    input:
    file_path: path of a individule csv file e.g. location of 21centfoxinc_sec_files.csv
    file_name: name of the file e.g 21centfoxinc_sec_files.csv
    
    output:
    a sigle pandas dataframe with all the original columns from the input file + a column for the 'cleaned' data
    
    dev:
    1) can add more output columns for features
    2) can further clean the data 
    
    '''
    
    ## read in single csv to pandas 
    individule_csv = pd.read_csv(file_path+"/"+file_name)
    processed_file = []
    
    ## create a connection with the url link and readin the raw file
    for url in individule_csv['sec_full_path']:
        print(url)
        text = request.urlopen(url).read().decode('utf8')
        soup = BeautifulSoup(text,'html.parser')
        
        ## clean raw text
        
        ## 1. remove html tags 
        ## 2. break the text by "\n"
        ## 3. remove the spaces in the front of and after each "\n"

        cleaned_text = '%%'.join(list(filter(None,
                                             [re.sub('[\t]+', ' ', i.strip()) for 
                                              i in soup.text.split('\n')])))
        
        ## find all tables
        raw_table = soup.find_all('table')
        
        
        ## clean all tables
        if not raw_table:

            cleaned_table = []
        else:
            
            '''
            cleaned_table = [[k[0],''.join(k[1:])] 
                             for k in [[j.replace('\n',"").strip() for j in re.split('  +',i)] for i in raw_table[0].get_text().split('\n\n')]]
            
            '''
     
            
            #cleaned_table = [re.split('  +',j) for j in [i for i in [h.get_text().split('\n\n') for h in raw_table]]]
            cleaned_table = [[[k[0],''.join(k[1:])] for k in 
             [[j.replace('\n',"").strip() 
               for j in re.split('  +',i)] 
              for i in l.get_text().split('\n\n')]] for l in raw_table]
            
            
            '''
            
            cleaned_table = [[k[0],''.join(k[1:])] 
                             for k in [[j.replace('\n',"").strip() 
                                        for j in re.split('  +',i)] 
                                       for i in [h.get_text().split('\n\n') for h in raw_table]]]            
            '''
        ## search the text
        Item_text = soup.findAll(text=re.compile("Item "))
        Item_category = [re.search('(?<=Item ).*', i).group(0) for i in Item_text]

        
        processed_file.append([url,
                               text,
                               cleaned_text,
                               raw_table,
                               cleaned_table,
                               Item_text,
                               Item_category])
    
    
    ## merge back to the original read in dataframe 
    clean_texts_df = pd.DataFrame(processed_file)
    clean_texts_df.columns = ['sec_full_path', 'text', 'cleaned_text',
                              'raw_table','cleaned_table',
                              'Item_text', 'Item_category']
    merged_df = pd.merge(left = individule_csv, right = clean_texts_df, on = 'sec_full_path')
    
    ## add one more column to indicate the file name 
    merged_df['file_name'] = file_name
    return merged_df
def folder_read_in_text(folder_path, ext = '.csv'):
    '''
    input: 
    folder_path: path of a individule csv file e.g. location of 21centfoxinc_sec_files.csv
    ext: extension of the files that are interested, default to be .csv 
    
    output:
    a sigle pandas dataframe with all the original columns from all the input files inside the folder
    + a column for the 'cleaned' data
    + a column for the file name 
    
    Utilize the single_read_in_text function 
txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-10-000091.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-10-000093.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-10-000095.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-10-000101.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-10-000102.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000004.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000008.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000010.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000014.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000016.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-11-071855.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-11-072458.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-11-084973.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000035.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000038.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000950123-11-041635.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000041.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-11-130267.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000061.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000064.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000066.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000069.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000072.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-11-211863.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-11-226167.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000078.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000080.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000086.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000088.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000090.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000094.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000097.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000099.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000102.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000107.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000109.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000113.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-11-000115.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000006.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000008.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000011.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000013.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-12-055727.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000025.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000027.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000031.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000032.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000034.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000037.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000039.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-12-250371.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000042.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-12-270874.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000063.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000066.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000068.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000073.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000075.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000080.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000083.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000085.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-12-000088.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-12-472897.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-12-487229.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-12-490742.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-12-498154.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-12-499645.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-12-504870.txt
# https://www.sec.gov/Archives/edgar/data/732717/0001193125-12-505129.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-13-000004.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-13-000007.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-13-000008.txt
# https://www.sec.gov/Archives/edgar/data/732717/0000732717-13-000010.txt
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in connect(self)
#    1391
# -> 1392             super().connect()
#    1393
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-7-d2827bc47d9e> in <module>()
#       1 working_file = folder_read_in_text(folder_path='C:/Users/li haoran/Documents/GitHub/Capstone_Vanguard_NLP_Prediction/Inputs',
# ----> 2                                    ext = '.csv')
#
# <ipython-input-6-bb3925120a92> in folder_read_in_text(folder_path, ext)
#     112
#     113     for i in txt_files:
# --> 114         temp_df = temp_df.append(single_read_in_text(file_path = folder_path,file_name = i), ignore_index=True)
#     115     return temp_df
#
# <ipython-input-6-bb3925120a92> in single_read_in_text(file_path, file_name)
#      21     for url in individule_csv['sec_full_path']:
#      22         print(url)
# ---> 23         text = request.urlopen(url).read().decode('utf8')
#      24         soup = BeautifulSoup(text,'html.parser')
#      25
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>

# %%
working_file[1:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ba041f883041> in <module>()
# ----> 1 working_file[1:10]
#
# NameError: name 'working_file' is not defined

# %%
working_file['cleaned_text'][2].split('%%')
# Out:
# "-----BEGIN PRIVACY-ENHANCED MESSAGE-----%%Proc-Type: 2001,MIC-CLEAR%%Originator-Name: keymaster@town.hall.org%%Originator-Key-Asymmetric:%%MFkwCgYEVQgBAQICAgADSwAwSAJBALeWW4xDV4i7+b6+UyPn5RtObb1cJ7VkACDq%%pKb9/DClgTKIm08lCfoilvi9Wl4SODbR1+1waHhiGmeZO8OdgLUCAwEAAQ==%%MIC-Info: RSA-MD5,RSA,%%GMQAlRnJvVLSy5tYNW+mtKTV/65v5fFNLQ176DahHwPr/SOIt/Pk794jNRnCxAXZ%%98Wfg25vcdOAKEqvBAUf7w==%%0000893220-94-000061.txt : 19940210%%0000893220-94-000061.hdr.sgml : 19940210%%ACCESSION NUMBER: 0000893220-94-000061%%CONFORMED SUBMISSION TYPE: 8-K%%PUBLIC DOCUMENT COUNT: 2%%CONFORMED PERIOD OF REPORT: 19940121%%ITEM INFORMATION: 5%%FILED AS OF DATE: 19940209%%FILER:%%COMPANY DATA:%%COMPANY CONFORMED NAME: BELL ATLANTIC CORP%%CENTRAL INDEX KEY: 0000732712%%STANDARD INDUSTRIAL CLASSIFICATION: 4813%%IRS NUMBER: 232259884%%STATE OF INCORPORATION: DE%%FISCAL YEAR END: 1231%%FILING VALUES:%%FORM TYPE: 8-K%%SEC ACT: 34%%SEC FILE NUMBER: 001-08606%%FILM NUMBER: 94505225%%BUSINESS ADDRESS:%%STREET 1: 1717 ARCH ST%%CITY: PHILADELPHIA%%STATE: PA%%ZIP: 19103%%BUSINESS PHONE: 2159636000%%8-K%%1%%FORM 8-K DATED JANUARY 21, 1994%%1%%SECURITIES AND EXCHANGE COMMISSION%%Washington, D.C. 20549%%Form 8-K%%CURRENT REPORT PURSUANT TO SECTION 13 OR 15(d) of the%%SECURITIES EXCHANGE ACT OF 1934%%Date of Report:                     January 21, 1994%%Exact name of registrant%%as specified in its charter:        BELL ATLANTIC CORPORATION%%Commission File No.:                1-8606%%State of Incorporation:             Delaware%%IRS Employer Identification No.:    23-2259884%%Address of principal%%executive offices:                  1717 Arch Street%%Philadelphia, Pennsylvania%%Zip Code:                           19103%%Registrant's telephone number,%%including area code:                (215) 963-6000%%Former name or former address,%%if changed since last report:       N/A%%2%%Item 5. Other Events.%%Bell Atlantic Corporation (the Company) on January 21, 1994 announced that it%%was reporting 1993 earnings of $3.22 per share, which included a one-time,%%non-cash charge of $.19 per share, or $85.0 million, for the adoption of a%%change in the method of accounting for postemployment benefits, versus $3.13%%per share in 1992.  Excluding this charge and the impact of 1993 tax%%legislation, 1993 earnings per share would have been $3.44.%%In addition to the one-time, non-cash charge for the change in the%%method of accounting for postemployment benefits (Statement of Financial%%Accounting Standards No. 112 [FAS 112]) and a net decrease of $.03 per share,%%or $11.4 million, for the effect of 1993 federal tax legislation, results for%%1993 also included extraordinary charges of $.13 per share, or $58.4 million,%%for early extinguishment of debt; and a net benefit of $.11 per share, or $51.0%%million, for other previously reported items.  Earnings for 1992 included a net%%charge of $.06 per share for previously disclosed items, including early%%extinguishment of debt.%%Net income for the year was $1.40 billion compared with $1.34 billion%%for 1992.  After excluding the above special items in both years, net income%%would have been $1.51 billion for 1993 and $1.37 billion for 1992.%%For the fourth quarter of 1993, earnings were $.76 per share, or%%$333.1 million, which included an extraordinary charge of $.01 per share, or%%$4.1 million, for early extinguishment of debt and a net decrease of $.02 per%%share, or $8.0 million, for the effect of 1993 federal tax legislation.  For%%the same period last year, earnings were $.74 per share, or $317.3 million,%%which included a $.02 per share extraordinary charge for early extinguishment%%of debt.  The one-time charge for FAS 112 was recorded retroactively to the%%first quarter of 1993.%%The Company stated that results from its landline network and domestic%%wireless businesses give it confidence that it can expect continued growth from%%these operations in 1994.  The Company's landline network business volumes and%%the demand for new products ...

# %%
working_file['Item_text'][2]
# Out:
# ["   2\nItem 5. Other Events.\n\nBell Atlantic Corporation (the Company) on January 21, 1994 announced that it\nwas reporting 1993 earnings of $3.22 per share, which included a one-time,\nnon-cash charge of $.19 per share, or $85.0 million, for the adoption of a\nchange in the method of accounting for postemployment benefits, versus $3.13\nper share in 1992.  Excluding this charge and the impact of 1993 tax\nlegislation, 1993 earnings per share would have been $3.44.\n\n         In addition to the one-time, non-cash charge for the change in the\nmethod of accounting for postemployment benefits (Statement of Financial\nAccounting Standards No. 112 [FAS 112]) and a net decrease of $.03 per share,\nor $11.4 million, for the effect of 1993 federal tax legislation, results for\n1993 also included extraordinary charges of $.13 per share, or $58.4 million,\nfor early extinguishment of debt; and a net benefit of $.11 per share, or $51.0\nmillion, for other previously reported items.  Earnings for 1992 included a net\ncharge of $.06 per share for previously disclosed items, including early\nextinguishment of debt.\n\n         Net income for the year was $1.40 billion compared with $1.34 billion\nfor 1992.  After excluding the above special items in both years, net income\nwould have been $1.51 billion for 1993 and $1.37 billion for 1992.\n\n         For the fourth quarter of 1993, earnings were $.76 per share, or\n$333.1 million, which included an extraordinary charge of $.01 per share, or\n$4.1 million, for early extinguishment of debt and a net decrease of $.02 per\nshare, or $8.0 million, for the effect of 1993 federal tax legislation.  For\nthe same period last year, earnings were $.74 per share, or $317.3 million,\nwhich included a $.02 per share extraordinary charge for early extinguishment\nof debt.  The one-time charge for FAS 112 was recorded retroactively to the\nfirst quarter of 1993.\n\n         The Company stated that results from its landline network and domestic\nwireless businesses give it confidence that it can expect continued growth from\nthese operations in 1994.  The Company's landline network business volumes and\nthe demand for new products and services continue on an upward trend.  Access\nminutes of use grew by 7.2 percent in 1993, and the Company reached the\nmilestone of one million Answer Call subscribers.  In the Company's wireless\nbusiness, results were dramatically higher than last year.  The cellular\nsubscriber base grew nearly 49 percent, surpassing the one million mark, and\nrevenue growth exceeded 30 percent for the year.\n\n         Wireless operations reported a total of approximately 1.04 million\nsubscribers at the end of 1993, an increase of 340,700 over 1992.  In the\nnetwork services companies, access lines at the end of the year totalled 18.6\nmillion, an increase of 464,600 lines, or 2.6 percent, versus the end of 1992.\nBusiness access\n",
#  '   4\nItem 7. Financial Statements and Exhibits.\n\n(c)  Exhibits.\n\nThe exhibit identified below is filed as an exhibit hereto.\n\nExhibit 99:\n\nUnaudited condensed consolidated statements of income, unaudited other selected\ndata and unaudited selected operating statistics for the three months and year\nended December 31, 1993 and 1992.\n']

# %%
working_file['raw_table'][0]
# Out:
# [<table>
#  <s> <c>
#  Date of Report:                              January 20, 1994
#
#  Exact name of registrant
#  as specified in its charter:                 BELL ATLANTIC CORPORATION
#
#  Commission File No.:                         1-8606
#
#  State of Incorporation:                      Delaware
#
#  IRS Employer Identification No.:             23-2259884
#
#  Address of principal
#  executive offices:                           1717 Arch Street
#                                               Philadelphia, Pennsylvania
#  Zip Code                                     19103
#
#  Registrant's telephone number,
#  including area code:                         (215) 963-6000
#
#  Former name or former address,
#  if changed since last report:                N/A
#  </c></s></table>]

# %%
working_file['cleaned_table'][0]
# Out:
# [[['Date of Report:', 'January 20, 1994'],
#   ['Exact name of registrantas specified in its charter:',
#    'BELL ATLANTIC CORPORATION'],
#   ['Commission File No.:', '1-8606'],
#   ['State of Incorporation:', 'Delaware'],
#   ['IRS Employer Identification No.:', '23-2259884'],
#   ['Address of principalexecutive offices:',
#    '1717 Arch StreetPhiladelphia, PennsylvaniaZip Code19103'],
#   ["Registrant's telephone number,including area code:", '(215) 963-6000'],
#   ['Former name or former address,if changed since last report:', 'N/A']]]

# %%
pd.DataFrame(working_file['cleaned_table'][0][0])
# Out:
#                                                    0  \
# 0                                    Date of Report:
# 1  Exact name of registrantas specified in its ch...
# 2                               Commission File No.:
# 3                            State of Incorporation:
# 4                   IRS Employer Identification No.:
# 5             Address of principalexecutive offices:
# 6  Registrant's telephone number,including area c...
# 7  Former name or former address,if changed since...
#
#                                                    1
# 0                                   January 20, 1994
# 1                          BELL ATLANTIC CORPORATION
# 2                                             1-8606
# 3                                           Delaware
# 4                                         23-2259884
# 5  1717 Arch StreetPhiladelphia, PennsylvaniaZip ...
# 6                                     (215) 963-6000
# 7                                                N/A

# %%
working_file['cleaned_table'][1]
# Out:
# []

# %%
working_file['cleaned_table'][2][0]
# Out:
# [['', ''],
#  ['',
#   'Three months endedYear endedDecember 31December 31-------------------------------------19931992*19931992*'],
#  ['',
#   'OPERATING REVENUES Communications andRelated Services$3,194.5$3,117.9$12,534.8$12,164.6 Financial, Real Estate,and Other Services122.7156.3455.4553.8'],
#  ['', 'Total operating revenues3,317.23,274.212,990.212,718.4'],
#  ['OPERATING EXPENSES Employee costs, including',
#   'benefits and taxes1,019.01,004.34,027.63,941.5 Depreciation andamortization649.8597.22,545.12,417.4 Other1,041.21,154.63,619.93,853.3'],
#  ['', 'Total operating expenses2,710.02,756.110,192.610,212.2'],
#  ['OPERATING INCOME', '607.2518.12,797.62,506.2'],
#  ['Other income and',
#   'expense, net29.142.388.1214.4Interest expense, excludingFinancial Services141.3162.3612.1694.9Income before provision for incometaxes, extraordinary item, andcumulative effect of changes inaccounting principles495.0398.12,273.62,025.7Provision for income taxes157.870.6792.0643.5Income before extraordinary itemand cumulative effect of changesin accounting principles337.2327.51,481.61,382.2Extraordinary item -- earlyextinguishment of debt,net of tax(4.1)(10.2)(58.4)(41.6)Cumulative effect of changes inaccounting principles:Income taxes----65.2--Postemployment benefits,net of tax----(85.0)--Total cumulative effectof changes in accountingprinciples----(19.8)--'],
#  ['NET INCOME', '$333.1$317.3$1,403.4$1,340.6']]

# %%
working_file['cleaned_table'][3]
# Out:
# [[['Date of Report:', 'February 14, 1994'],
#   ['Exact name of registrantas specified in its charter:',
#    'BELL ATLANTIC CORPORATION'],
#   ['Commission File No.:', '1-8606'],
#   ['State of Incorporation:', 'Delaware'],
#   ['IRS Employer Identification No.:', '23-2259884'],
#   ['Address of principalexecutive offices:',
#    '1717 Arch StreetPhiladelphia, PennsylvaniaZip Code19103'],
#   ["Registrant's telephone number,including area code:", '(215) 963-6000'],
#   ['Former name or former address,if changed since last report:', 'N/A']]]

# %%
working_file['raw_table'][2][0]
# Out:
# <table>
# <caption>
#                                                            Three months ended                         Year ended
#                                                                December 31                            December 31
#                                                            ------------------                     -------------------
#                                                         1993                1992*              1993                1992*
#
# <s> <c> <c> <c> <c>
# OPERATING REVENUES
#  Communications and
#   Related Services                                    $3,194.5             $3,117.9          $12,534.8            $12,164.6
#  Financial, Real Estate,
#   and Other Services                                     122.7                156.3              455.4                553.8
#
#      Total operating revenues                          3,317.2              3,274.2           12,990.2             12,718.4
#
# OPERATING EXPENSES
#  Employee costs, including
#    benefits and taxes                                  1,019.0              1,004.3            4,027.6              3,941.5
#  Depreciation and
#    amortization                                          649.8                597.2            2,545.1              2,417.4
#  Other                                                 1,041.2              1,154.6            3,619.9              3,853.3
#
#      Total operating expenses                          2,710.0              2,756.1           10,192.6             10,212.2
#
# OPERATING INCOME                                         607.2                518.1            2,797.6              2,506.2
#
# Other income and
#   expense, net                                            29.1                 42.3               88.1                214.4
# Interest expense, excluding
#   Financial Services                                     141.3                162.3              612.1                694.9
# Income before provision for income
#   taxes, extraordinary item, and
#   cumulative effect of changes in
#   accounting principles                                  495.0                398.1            2,273.6              2,025.7
# Provision for income taxes                               157.8                 70.6              792.0                643.5
# Income before extraordinary item
#   and cumulative effect of changes
#   in accounting principles                               337.2                327.5            1,481.6              1,382.2
# Extraordinary item -- early
#   extinguishment of debt,
#   net of tax                                              (4.1)               (10.2)             (58.4)               (41.6)
# Cumulative effect of changes in
#   accounting principles:
#     Income taxes                                          --                   --                 65.2                 --
#     Postemployment benefits,
#       net of tax                                          --                   --                (85.0)                --
#        Total cumulative effect
#          of changes in accounting
#          principles                                       --                   --                (19.8)                --
#
# NET INCOME                                            $  333.1             $  317.3           $1,403.4             $1,340.6
# </c></c></c></c></s></caption></table>

# %%
working_file['raw_table'][2][0].get_text()
# Out:
# '\n\n                                                           Three months ended                         Year ended\n                                                               December 31                            December 31    \n                                                           ------------------                     -------------------\n                                                        1993                1992*              1993                1992*\n\n    \nOPERATING REVENUES\n Communications and\n  Related Services                                    $3,194.5             $3,117.9          $12,534.8            $12,164.6\n Financial, Real Estate,\n  and Other Services                                     122.7                156.3              455.4                553.8\n\n     Total operating revenues                          3,317.2              3,274.2           12,990.2             12,718.4\n\nOPERATING EXPENSES\n Employee costs, including\n   benefits and taxes                                  1,019.0              1,004.3            4,027.6              3,941.5\n Depreciation and\n   amortization                                          649.8                597.2            2,545.1              2,417.4\n Other                                                 1,041.2              1,154.6            3,619.9              3,853.3\n\n     Total operating expenses                          2,710.0              2,756.1           10,192.6             10,212.2\n\nOPERATING INCOME                                         607.2                518.1            2,797.6              2,506.2\n\nOther income and\n  expense, net                                            29.1                 42.3               88.1                214.4\nInterest expense, excluding\n  Financial Services                                     141.3                162.3              612.1                694.9\nIncome before provision for income\n  taxes, extraordinary item, and\n  cumulative effect of changes in\n  accounting principles                                  495.0                398.1            2,273.6              2,025.7\nProvision for income taxes                               157.8                 70.6              792.0                643.5\nIncome before extraordinary item\n  and cumulative effect of changes\n  in accounting principles                               337.2                327.5            1,481.6              1,382.2\nExtraordinary item -- early\n  extinguishment of debt,\n  net of tax                                              (4.1)               (10.2)             (58.4)               (41.6)\nCumulative effect of changes in\n  accounting principles:\n    Income taxes                                          --                   --                 65.2                 --\n    Postemployment benefits,\n      net of tax                                          --                   --                (85.0)                --\n       Total cumulative effect\n         of changes in accounting\n         principles                                       --                   --                (19.8)                --\n\nNET INCOME                                            $  333.1             $  317.3           $1,403.4             $1,340.6\n'

# %%
working_file['raw_table'][2][0].get_text().split('\n\n')[0]
# Out:
# ''

# %%
working_file['raw_table'][2][0].get_text().split('\n\n')[1]
# Out:
# '                                                           Three months ended                         Year ended\n                                                               December 31                            December 31    \n                                                           ------------------                     -------------------\n                                                        1993                1992*              1993                1992*'

# %%
working_file['raw_table'][2][0].get_text().split('\n\n')[3]
# Out:
# '     Total operating revenues                          3,317.2              3,274.2           12,990.2             12,718.4'

# %%
working_file['raw_table'][2][0].get_text().split('\n\n')[4]
# Out:
# 'OPERATING EXPENSES\n Employee costs, including\n   benefits and taxes                                  1,019.0              1,004.3            4,027.6              3,941.5\n Depreciation and\n   amortization                                          649.8                597.2            2,545.1              2,417.4\n Other                                                 1,041.2              1,154.6            3,619.9              3,853.3'

# %%
print(working_file['raw_table'][2][0].get_text().split('\n\n')[4])
# Out:
# OPERATING EXPENSES
#  Employee costs, including
#    benefits and taxes                                  1,019.0              1,004.3            4,027.6              3,941.5
#  Depreciation and
#    amortization                                          649.8                597.2            2,545.1              2,417.4
#  Other                                                 1,041.2              1,154.6            3,619.9              3,853.3

# %%
[ [[j.replace('\n',"").strip() 
   for j in re.split('  +',i)] 
  for i in working_file['raw_table'][2][0].get_text().split('\n\n')]]
# Out:
# [[[''],
#   ['',
#    'Three months ended',
#    'Year ended',
#    'December 31',
#    'December 31',
#    '',
#    '------------------',
#    '-------------------',
#    '1993',
#    '1992*',
#    '1993',
#    '1992*'],
#   ['',
#    'OPERATING REVENUES Communications and',
#    'Related Services',
#    '$3,194.5',
#    '$3,117.9',
#    '$12,534.8',
#    '$12,164.6 Financial, Real Estate,',
#    'and Other Services',
#    '122.7',
#    '156.3',
#    '455.4',
#    '553.8'],
#   ['',
#    'Total operating revenues',
#    '3,317.2',
#    '3,274.2',
#    '12,990.2',
#    '12,718.4'],
#   ['OPERATING EXPENSES Employee costs, including',
#    'benefits and taxes',
#    '1,019.0',
#    '1,004.3',
#    '4,027.6',
#    '3,941.5 Depreciation and',
#    'amortization',
#    '649.8',
#    '597.2',
#    '2,545.1',
#    '2,417.4 Other',
#    '1,041.2',
#    '1,154.6',
#    '3,619.9',
#    '3,853.3'],
#   ['',
#    'Total operating expenses',
#    '2,710.0',
#    '2,756.1',
#    '10,192.6',
#    '10,212.2'],
#   ['OPERATING INCOME', '607.2', '518.1', '2,797.6', '2,506.2'],
#   ['Other income and',
#    'expense, net',
#    '29.1',
#    '42.3',
#    '88.1',
#    '214.4Interest expense, excluding',
#    'Financial Services',
#    '141.3',
#    '162.3',
#    '612.1',
#    '694.9Income before provision for income',
#    'taxes, extraordinary item, and',
#    'cumulative effect of changes in',
#    'accounting principles',
#    '495.0',
#    '398.1',
#    '2,273.6',
#    '2,025.7Provision for income taxes',
#    '157.8',
#    '70.6',
#    '792.0',
#    '643.5Income before extraordinary item',
#    'and cumulative effect of changes',
#    'in accounting principles',
#    '337.2',
#    '327.5',
#    '1,481.6',
#    '1,382.2Extraordinary item -- early',
#    'extinguishment of debt,',
#    'net of tax',
#    '(4.1)',
#    '(10.2)',
#    '(58.4)',
#    '(41.6)Cumulative effect of changes in',
#    'accounting principles:',
#    'Income taxes',
#    '--',
#    '--',
#    '65.2',
#    '--',
#    'Postemployment benefits,',
#    'net of tax',
#    '--',
#    '--',
#    '(85.0)',
#    '--',
#    'Total cumulative effect',
#    'of changes in accounting',
#    'principles',
#    '--',
#    '--',
#    '(19.8)',
#    '--'],
#   ['NET INCOME', '$', '333.1', '$', '317.3', '$1,403.4', '$1,340.6']]]

# %%
[[k[0],''.join(k[1:])] for k in 
 [[j.replace('\n',"").strip() 
   for j in re.split('  +',i)] 
  for i in working_file['raw_table'][2][0].get_text().split('\n\n')]]
# Out:
# [['', ''],
#  ['',
#   'Three months endedYear endedDecember 31December 31-------------------------------------19931992*19931992*'],
#  ['',
#   'OPERATING REVENUES Communications andRelated Services$3,194.5$3,117.9$12,534.8$12,164.6 Financial, Real Estate,and Other Services122.7156.3455.4553.8'],
#  ['', 'Total operating revenues3,317.23,274.212,990.212,718.4'],
#  ['OPERATING EXPENSES Employee costs, including',
#   'benefits and taxes1,019.01,004.34,027.63,941.5 Depreciation andamortization649.8597.22,545.12,417.4 Other1,041.21,154.63,619.93,853.3'],
#  ['', 'Total operating expenses2,710.02,756.110,192.610,212.2'],
#  ['OPERATING INCOME', '607.2518.12,797.62,506.2'],
#  ['Other income and',
#   'expense, net29.142.388.1214.4Interest expense, excludingFinancial Services141.3162.3612.1694.9Income before provision for incometaxes, extraordinary item, andcumulative effect of changes inaccounting principles495.0398.12,273.62,025.7Provision for income taxes157.870.6792.0643.5Income before extraordinary itemand cumulative effect of changesin accounting principles337.2327.51,481.61,382.2Extraordinary item -- earlyextinguishment of debt,net of tax(4.1)(10.2)(58.4)(41.6)Cumulative effect of changes inaccounting principles:Income taxes----65.2--Postemployment benefits,net of tax----(85.0)--Total cumulative effectof changes in accountingprinciples----(19.8)--'],
#  ['NET INCOME', '$333.1$317.3$1,403.4$1,340.6']]

# %%
mystr = StringIO(working_file[0:1]['table'][0][0].get_text())
df = pd.read_csv(mystr, header=None, delimiter=':')
df
# Out:
#                                                     0  \
# 0                                      Date of Report
# 1                            Exact name of registrant
# 2                         as specified in its charter
# 3                                 Commission File No.
# 4                              State of Incorporation
# 5                     IRS Employer Identification No.
# 6                                Address of principal
# 7                                   executive offices
# 8                                                P...
# 9   Zip Code                                     1...
# 10                     Registrant's telephone number,
# 11                                including area code
# 12                     Former name or former address,
# 13                       if changed since last report
#
#                                                  1
# 0                                 January 20, 1994
# 1                                              NaN
# 2                        BELL ATLANTIC CORPORATION
# 3                                           1-8606
# 4                                         Delaware
# 5                                       23-2259884
# 6                                              NaN
# 7                                 1717 Arch Street
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                  (215) 963-6000
# 12                                             NaN
# 13                                             N/A

# %%
working_file[0:1]['raw_table'][0][0]
# Out:
# <table>
# <s> <c>
# Date of Report:                              January 20, 1994
#
# Exact name of registrant
# as specified in its charter:                 BELL ATLANTIC CORPORATION
#
# Commission File No.:                         1-8606
#
# State of Incorporation:                      Delaware
#
# IRS Employer Identification No.:             23-2259884
#
# Address of principal
# executive offices:                           1717 Arch Street
#                                              Philadelphia, Pennsylvania
# Zip Code                                     19103
#
# Registrant's telephone number,
# including area code:                         (215) 963-6000
#
# Former name or former address,
# if changed since last report:                N/A
# </c></s></table>

# %%
working_file[0:1]['raw_table'][0][0].get_text()
# Out:
# "\n \nDate of Report:                              January 20, 1994\n\nExact name of registrant\nas specified in its charter:                 BELL ATLANTIC CORPORATION\n\nCommission File No.:                         1-8606\n\nState of Incorporation:                      Delaware\n\nIRS Employer Identification No.:             23-2259884\n\nAddress of principal\nexecutive offices:                           1717 Arch Street\n                                             Philadelphia, Pennsylvania\nZip Code                                     19103\n\nRegistrant's telephone number,\nincluding area code:                         (215) 963-6000\n\nFormer name or former address,\nif changed since last report:                N/A\n"

# %%
pd.DataFrame([[k[0],''.join(k[1:])] for k in 
 [[j.replace('\n',"").strip() 
   for j in re.split('  +',i)] 
  for i in working_file[0:1]['raw_table'][0][0].get_text().split('\n\n')]])
# Out:
#                                                    0  \
# 0                                    Date of Report:
# 1  Exact name of registrantas specified in its ch...
# 2                               Commission File No.:
# 3                            State of Incorporation:
# 4                   IRS Employer Identification No.:
# 5             Address of principalexecutive offices:
# 6  Registrant's telephone number,including area c...
# 7  Former name or former address,if changed since...
#
#                                                    1
# 0                                   January 20, 1994
# 1                          BELL ATLANTIC CORPORATION
# 2                                             1-8606
# 3                                           Delaware
# 4                                         23-2259884
# 5  1717 Arch StreetPhiladelphia, PennsylvaniaZip ...
# 6                                     (215) 963-6000
# 7                                                N/A

# %%
working_file['raw_table'][2]
# Out:
# [<table>
#  <caption>
#                                                             Three months ended                         Year ended
#                                                                 December 31                            December 31
#                                                             ------------------                     -------------------
#                                                          1993                1992*              1993                1992*
#
#  <s> <c> <c> <c> <c>
#  OPERATING REVENUES
#   Communications and
#    Related Services                                    $3,194.5             $3,117.9          $12,534.8            $12,164.6
#   Financial, Real Estate,
#    and Other Services                                     122.7                156.3              455.4                553.8
#
#       Total operating revenues                          3,317.2              3,274.2           12,990.2             12,718.4
#
#  OPERATING EXPENSES
#   Employee costs, including
#     benefits and taxes                                  1,019.0              1,004.3            4,027.6              3,941.5
#   Depreciation and
#     amortization                                          649.8                597.2            2,545.1              2,417.4
#   Other                                                 1,041.2              1,154.6            3,619.9              3,853.3
#
#       Total operating expenses                          2,710.0              2,756.1           10,192.6             10,212.2
#
#  OPERATING INCOME                                         607.2                518.1            2,797.6              2,506.2
#
#  Other income and
#    expense, net                                            29.1                 42.3               88.1                214.4
#  Interest expense, excluding
#    Financial Services                                     141.3                162.3              612.1                694.9
#  Income before provision for income
#    taxes, extraordinary item, and
#    cumulative effect of changes in
#    accounting principles                                  495.0                398.1            2,273.6              2,025.7
#  Provision for income taxes                               157.8                 70.6              792.0                643.5
#  Income before extraordinary item
#    and cumulative effect of changes
#    in accounting principles                               337.2                327.5            1,481.6              1,382.2
#  Extraordinary item -- early
#    extinguishment of debt,
#    net of tax                                              (4.1)               (10.2)             (58.4)               (41.6)
#  Cumulative effect of changes in
#    accounting principles:
#      Income taxes                                          --                   --                 65.2                 --
#      Postemployment benefits,
#        net of tax                                          --                   --                (85.0)                --
#         Total cumulative effect
#           of changes in accounting
#           principles                                       --                   --                (19.8)                --
#
#  NET INCOME                                            $  333.1             $  317.3           $1,403.4             $1,340.6
#  </c></c></c></c></s></caption></table>, <table>
#  <caption>
#                                                                 Three months ended                        Year ended
#                                                                     December 31                           December 31
#                                                                 ------------------                    -------------------
#                                                             1993                 1992               1993                1992
#
#  <s> <c> <c> <c> <c>
#  PER COMMON SHARE AMOUNTS
#   Income before extraordinary item and
#    cumulative effect of changes in
#    accounting principles                                     $.77                 $.76              $3.39               $3.23
#   Extraordinary item -- early ex-
#   tinguishment of debt, net of tax                           (.01)                (.02)              (.13)               (.10)
#   Cumulative effect of changes in
#    accounting principles                                       --                   --               (.04)                 --
#
#    NET INCOME                                                $.76                 $.74              $3.22               $3.13
#
#  DIVIDENDS DECLARED PER
#   COMMON SHARE                                               $.67                 $.65              $2.68               $2.60
#
#  WEIGHTED AVERAGE NUMBER OF
#   COMMON AND EQUIVALENT
#   SHARES OUTSTANDING                                        437.5                434.5              436.3               433.0
#  </c></c></c></c></s></caption></table>, <table>
#  <caption>
#  OTHER SELECTED DATA
#  - -------------------
#                                                                                         December 31
#                                                                                      ----------------
#
#                                                                                   1993               1992
#                                                                                   ----               ----
#
#  <s> <c> <c>
#  Return on Average Common Equity
#    Three months ended                                                            16.0%                16.1%
#    Year ended                                                                    17.3%                17.4%
#
#  Total Assets (millions)                                                     $29,544.2            $28,099.5
#
#  Total Employees                                                                73,600               71,400
#  </c></c></s></caption></table>, <table>
#  <caption>
#                                                                                      Year Ended December 31,
#                                                                                1993                       1992*
#                                                                           --------------              -------------
#
#  <s> <c> <c>
#  CASH FLOWS FROM OPERATING ACTIVITIES
#     Net income                                                                $1,403.4                   $1,340.6
#     Depreciation and amortization                                              2,545.1                    2,417.4
#     Extraordinary item -- early extinguishment
#        of debt, net of tax                                                        58.4                       41.6
#     Cumulative effect of changes in
#        accounting principles                                                      19.8                        --
#     Other, net                                                                   207.3                      108.1
#
#  NET CASH PROVIDED BY OPERATING
#     ACTIVITIES                                                                 4,234.0                    3,907.7
#
#  NET CASH USED IN INVESTING
#     ACTIVITIES                                                                (2,936.3)                  (1,995.8)
#
#  NET CASH USED IN FINANCING
#     ACTIVITIES                                                                (1,447.6)                  (1,747.6)
#
#  Increase (Decrease) in Cash and
#     Cash Equivalents                                                            (149.9)                     164.3
#
#  Cash and Cash Equivalents,
#     Beginning of Year                                                            296.0                      131.7
#
#  Cash and Cash Equivalents,
#     End of Year                                                                 $146.1                     $296.0
#
#  </c></c></s></caption></table>, <table>
#  <caption>
#                                                             December 31
#                                                           ----------------
#
#                                                       1993                1992                 Percent Change
#                                                       ----                ----                 --------------
#
#  <s> <c> <c> <c>
#  Total Owned POPs                                    35,238              34,200                      3.0
#
#  Controlled MSA POPs                                 27,883              27,400                      1.8
#
#  Controlled RSA POPs(1)                               3,706               3,262                     13.6
#
#  Subscribers in
#   Controlled Markets                                  964.9               651.3                     48.2
#
#  Controlled Penetration(2)                            3.05%               2.12%                     43.8
#
#  Total Subscribers(3)                               1,039.1               698.4                     48.8
#
#  Fourth-Quarter Cellular
#   Operations Revenue                               $223,197            $163,500                     36.5
#
#  Year-to-Date Cellular
#   Operations Revenue                               $773,448            $586,124                     32.0
#
#  Fourth-Quarter Cellular
#   Operations Revenue per
#   Subscriber per Month(3)                               $77                 $83                    (7.2)
#
#  Year-to-Date Cellular
#   Operations Revenue per
#   Subscriber per Month(3)                               $77                 $83                    (7.2)
#  </c></c></c></s></caption></table>]

# %%
working_file['cleaned_table'][2]
# Out:
# [[['', ''],
#   ['',
#    'Three months endedYear endedDecember 31December 31-------------------------------------19931992*19931992*'],
#   ['',
#    'OPERATING REVENUES Communications andRelated Services$3,194.5$3,117.9$12,534.8$12,164.6 Financial, Real Estate,and Other Services122.7156.3455.4553.8'],
#   ['', 'Total operating revenues3,317.23,274.212,990.212,718.4'],
#   ['OPERATING EXPENSES Employee costs, including',
#    'benefits and taxes1,019.01,004.34,027.63,941.5 Depreciation andamortization649.8597.22,545.12,417.4 Other1,041.21,154.63,619.93,853.3'],
#   ['', 'Total operating expenses2,710.02,756.110,192.610,212.2'],
#   ['OPERATING INCOME', '607.2518.12,797.62,506.2'],
#   ['Other income and',
#    'expense, net29.142.388.1214.4Interest expense, excludingFinancial Services141.3162.3612.1694.9Income before provision for incometaxes, extraordinary item, andcumulative effect of changes inaccounting principles495.0398.12,273.62,025.7Provision for income taxes157.870.6792.0643.5Income before extraordinary itemand cumulative effect of changesin accounting principles337.2327.51,481.61,382.2Extraordinary item -- earlyextinguishment of debt,net of tax(4.1)(10.2)(58.4)(41.6)Cumulative effect of changes inaccounting principles:Income taxes----65.2--Postemployment benefits,net of tax----(85.0)--Total cumulative effectof changes in accountingprinciples----(19.8)--'],
#   ['NET INCOME', '$333.1$317.3$1,403.4$1,340.6']],
#  [['', ''],
#   ['',
#    'Three months endedYear endedDecember 31December 31-------------------------------------1993199219931992'],
#   ['',
#    'PER COMMON SHARE AMOUNTS Income before extraordinary item andcumulative effect of changes inaccounting principles$.77$.76$3.39$3.23 Extraordinary item -- early ex- tinguishment of debt, net of tax(.01)(.02)(.13)(.10) Cumulative effect of changes inaccounting principles----(.04)--'],
#   ['', 'NET INCOME$.76$.74$3.22$3.13'],
#   ['DIVIDENDS DECLARED PER COMMON SHARE', '$.67$.65$2.68$2.60'],
#   ['WEIGHTED AVERAGE NUMBER OF COMMON AND EQUIVALENT SHARES OUTSTANDING',
#    '437.5434.5436.3433.0']],
#  [['', ''],
#   ['OTHER SELECTED DATA- -------------------', 'December 31----------------'],
#   ['', '19931992--------'],
#   ['',
#    'Return on Average Common EquityThree months ended16.0%16.1%Year ended17.3%17.4%'],
#   ['Total Assets (millions)', '$29,544.2$28,099.5'],
#   ['Total Employees', '73,60071,400']],
#  [['', ''],
#   ['', 'Year Ended December 31,19931992*---------------------------'],
#   ['',
#    'CASH FLOWS FROM OPERATING ACTIVITIESNet income$1,403.4$1,340.6Depreciation and amortization2,545.12,417.4Extraordinary item -- early extinguishmentof debt, net of tax58.441.6Cumulative effect of changes inaccounting principles19.8--Other, net207.3108.1'],
#   ['NET CASH PROVIDED BY OPERATING', 'ACTIVITIES4,234.03,907.7'],
#   ['NET CASH USED IN INVESTING', 'ACTIVITIES(2,936.3)(1,995.8)'],
#   ['NET CASH USED IN FINANCING', 'ACTIVITIES(1,447.6)(1,747.6)'],
#   ['Increase (Decrease) in Cash and', 'Cash Equivalents(149.9)164.3'],
#   ['Cash and Cash Equivalents,', 'Beginning of Year296.0131.7'],
#   ['Cash and Cash Equivalents,', 'End of Year$146.1$296.0'],
#   ['', '']],
#  [['', ''],
#   ['', 'December 31----------------'],
#   ['', '19931992Percent Change----------------------'],
#   ['', 'Total Owned POPs35,23834,2003.0'],
#   ['Controlled MSA POPs', '27,88327,4001.8'],
#   ['Controlled RSA POPs(1)', '3,7063,26213.6'],
#   ['Subscribers in Controlled Markets', '964.9651.348.2'],
#   ['Controlled Penetration(2)', '3.05%2.12%43.8'],
#   ['Total Subscribers(3)', '1,039.1698.448.8'],
#   ['Fourth-Quarter Cellular Operations Revenue', '$223,197$163,50036.5'],
#   ['Year-to-Date Cellular Operations Revenue', '$773,448$586,12432.0'],
#   ['Fourth-Quarter Cellular Operations Revenue per Subscriber per Month(3)',
#    '$77$83(7.2)'],
#   ['Year-to-Date Cellular Operations Revenue per Subscriber per Month(3)',
#    '$77$83(7.2)']]]

# %%
[[j for j in re.split('  +',i)] 
           for i in working_file['raw_table'][2][0].get_text().split('\n\n')]
# Out:
# [[''],
#  ['',
#   'Three months ended',
#   'Year ended\n',
#   'December 31',
#   'December 31',
#   '\n',
#   '------------------',
#   '-------------------\n',
#   '1993',
#   '1992*',
#   '1993',
#   '1992*'],
#  ['',
#   '\nOPERATING REVENUES\n Communications and\n',
#   'Related Services',
#   '$3,194.5',
#   '$3,117.9',
#   '$12,534.8',
#   '$12,164.6\n Financial, Real Estate,\n',
#   'and Other Services',
#   '122.7',
#   '156.3',
#   '455.4',
#   '553.8'],
#  ['',
#   'Total operating revenues',
#   '3,317.2',
#   '3,274.2',
#   '12,990.2',
#   '12,718.4'],
#  ['OPERATING EXPENSES\n Employee costs, including\n',
#   'benefits and taxes',
#   '1,019.0',
#   '1,004.3',
#   '4,027.6',
#   '3,941.5\n Depreciation and\n',
#   'amortization',
#   '649.8',
#   '597.2',
#   '2,545.1',
#   '2,417.4\n Other',
#   '1,041.2',
#   '1,154.6',
#   '3,619.9',
#   '3,853.3'],
#  ['',
#   'Total operating expenses',
#   '2,710.0',
#   '2,756.1',
#   '10,192.6',
#   '10,212.2'],
#  ['OPERATING INCOME', '607.2', '518.1', '2,797.6', '2,506.2'],
#  ['Other income and\n',
#   'expense, net',
#   '29.1',
#   '42.3',
#   '88.1',
#   '214.4\nInterest expense, excluding\n',
#   'Financial Services',
#   '141.3',
#   '162.3',
#   '612.1',
#   '694.9\nIncome before provision for income\n',
#   'taxes, extraordinary item, and\n',
#   'cumulative effect of changes in\n',
#   'accounting principles',
#   '495.0',
#   '398.1',
#   '2,273.6',
#   '2,025.7\nProvision for income taxes',
#   '157.8',
#   '70.6',
#   '792.0',
#   '643.5\nIncome before extraordinary item\n',
#   'and cumulative effect of changes\n',
#   'in accounting principles',
#   '337.2',
#   '327.5',
#   '1,481.6',
#   '1,382.2\nExtraordinary item -- early\n',
#   'extinguishment of debt,\n',
#   'net of tax',
#   '(4.1)',
#   '(10.2)',
#   '(58.4)',
#   '(41.6)\nCumulative effect of changes in\n',
#   'accounting principles:\n',
#   'Income taxes',
#   '--',
#   '--',
#   '65.2',
#   '--\n',
#   'Postemployment benefits,\n',
#   'net of tax',
#   '--',
#   '--',
#   '(85.0)',
#   '--\n',
#   'Total cumulative effect\n',
#   'of changes in accounting\n',
#   'principles',
#   '--',
#   '--',
#   '(19.8)',
#   '--'],
#  ['NET INCOME', '$', '333.1', '$', '317.3', '$1,403.4', '$1,340.6\n']]

# %%
[[k[0],''.join(k[1:])] 
 for k in [[j.replace('\n',"").strip() 
   for j in re.split('  +',i)] 
           for i in working_file['raw_table'][2][0].get_text().split('\n\n')]]
# Out:
# [['', ''],
#  ['',
#   'Three months endedYear endedDecember 31December 31-------------------------------------19931992*19931992*'],
#  ['',
#   'OPERATING REVENUES Communications andRelated Services$3,194.5$3,117.9$12,534.8$12,164.6 Financial, Real Estate,and Other Services122.7156.3455.4553.8'],
#  ['', 'Total operating revenues3,317.23,274.212,990.212,718.4'],
#  ['OPERATING EXPENSES Employee costs, including',
#   'benefits and taxes1,019.01,004.34,027.63,941.5 Depreciation andamortization649.8597.22,545.12,417.4 Other1,041.21,154.63,619.93,853.3'],
#  ['', 'Total operating expenses2,710.02,756.110,192.610,212.2'],
#  ['OPERATING INCOME', '607.2518.12,797.62,506.2'],
#  ['Other income and',
#   'expense, net29.142.388.1214.4Interest expense, excludingFinancial Services141.3162.3612.1694.9Income before provision for incometaxes, extraordinary item, andcumulative effect of changes inaccounting principles495.0398.12,273.62,025.7Provision for income taxes157.870.6792.0643.5Income before extraordinary itemand cumulative effect of changesin accounting principles337.2327.51,481.61,382.2Extraordinary item -- earlyextinguishment of debt,net of tax(4.1)(10.2)(58.4)(41.6)Cumulative effect of changes inaccounting principles:Income taxes----65.2--Postemployment benefits,net of tax----(85.0)--Total cumulative effectof changes in accountingprinciples----(19.8)--'],
#  ['NET INCOME', '$333.1$317.3$1,403.4$1,340.6']]

# %%
#single_read_in_text('C:/Users/li haoran/Desktop/New folder','21centfoxinc_sec_files.csv')
working_file = folder_read_in_text(folder_path='C:/Users/li haoran/Documents/GitHub/Capstone_Vanguard_NLP_Prediction/Inputs',
                                   ext = '.csv')

# %% [markdown]
# ## Write Output

# %%
working_file.to_csv('C:/Users/li haoran/Desktop/sec files/cleaned_data.csv', sep='|', encoding='utf-8')

# %% [markdown]
# # Further processing

# %% [markdown]
# ## Read documents

# %%
file_path = 'C:/Users/li haoran/Desktop/sec files/cleaned_data.csv'
cleaned_data = pd.read_csv(file_path, sep='|', encoding='utf-8')

# %% [markdown]
# ## Further clean the data

# %%
words = set(nltk.corpus.words.words())
cleaned_data['only_eng_words'] = cleaned_data['text'].apply(lambda x: " ".join(w for w in nltk.wordpunct_tokenize(x) \
                                      if w.lower() in words))
cleaned_data['evy_gram_1_3'] =cleaned_data['only_eng_words'].apply(lambda x: [' '.join(ng) for ng in everygrams(word_tokenize(x), 1, 4)])

# %%
cleaned_data[['file_name', 'doccount']]\
.groupby(['file_name'])\
.agg(['count','sum'])\
.reset_index()
# Out:
#                     file_name doccount
#                                  count     sum
# 0  21centfoxinc_sec_files.csv     1048  3978.0
# 1        attinc_sec_files.csv      555  3383.0
# 2       cbscorp_sec_files.csv      385  2578.0
# 3   comcastcorp_sec_files.csv      277  2735.0
# 4    verizoncom_sec_files.csv      525  3319.0

# %% [markdown]
# ## Write Output

# %%
cleaned_data.to_csv('C:/Users/li haoran/Desktop/sec files/cleaned_data_updated.csv', sep='|', encoding='utf-8')

# %%
cleaned_data[cleaned_data['file_name']=='21centfoxinc_sec_files.csv']\
.to_csv('C:/Users/li haoran/Desktop/sec files/cleaned_data_updated_21centfoxinc_sec_files.csv', sep='|', encoding='utf-8')

cleaned_data[cleaned_data['file_name']=='attinc_sec_files.csv']\
.to_csv('C:/Users/li haoran/Desktop/sec files/cleaned_data_updated_attinc_sec_files.csv', sep='|', encoding='utf-8')

cleaned_data[cleaned_data['file_name']=='cbscorp_sec_files.csv']\
.to_csv('C:/Users/li haoran/Desktop/sec files/cleaned_data_updated_cbscorp_sec_files.csv', sep='|', encoding='utf-8')

cleaned_data[cleaned_data['file_name']=='comcastcorp_sec_files.csv']\
.to_csv('C:/Users/li haoran/Desktop/sec files/cleaned_data_updated_comcastcorp_sec_files.csv', sep='|', encoding='utf-8')

cleaned_data[cleaned_data['file_name']=='verizoncom_sec_files.csv']\
.to_csv('C:/Users/li haoran/Desktop/sec files/cleaned_data_updated_verizoncom_sec_files.csv', sep='|', encoding='utf-8')

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Read documents

# %%
## Full data
file_path = 'C:/Users/li haoran/Desktop/sec files/cleaned_data.csv'
cleaned_data = pd.read_csv(file_path, sep='|', encoding='utf-8')

# %%
## cleaned_data_updated_verizoncom_sec_files.csv
file_path = 'C:/Users/li haoran/Desktop/sec files/cleaned_data_updated_verizoncom_sec_files.csv'
cleaned_verizon_data = pd.read_csv(file_path, sep='|', encoding='utf-8')

# %% [markdown]
# ## EDA

# %%
table1 = cleaned_data[['file_name', 'doccount']]\
.groupby(['file_name'])\
.agg(['count','sum'])\
.reset_index()
print(list(table1))
table1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7a01fe7377e6> in <module>()
# ----> 1 table1 = cleaned_data[['file_name', 'doccount']].groupby(['file_name']).agg(['count','sum']).reset_index()
#       2 print(list(table1))
#       3 table1
#
# NameError: name 'cleaned_data' is not defined

# %%
trace1 = go.Bar(x = table1['file_name'], 
                y = table1['doccount']['count'],
                name = 'filing count')

trace2 = go.Bar(x = table1['file_name'],
                y = table1['doccount']['sum'],
                name = 'document count')

data = [trace1,trace2]


iplot({
    "data":data,
    "layout":go.Layout(title="Distribution of number of emails received", 
                       xaxis={'title':'Num of emails'}, 
                       yaxis={'title':'Percentage of people received %'})})

# %%
table2 = cleaned_data[['file_name','form','doccount']]\
.groupby(['file_name','form'])\
.agg(['count','sum'])\
.sort_values(by=['file_name'])\
.reset_index()
print(list(table2))
table2

# %% [markdown]
# ## Extract Features

# %% [markdown]
# Notes:
# It is very very very very hard to parse old sec financial table, more recent files are easier
#
# https://www.sec.gov/investor/pubs/readan8k.pdf
#
# https://github.com/ragraw26/Edgar-COMPANY-FILINGS-Web-Scrapping-Data-Analysis/blob/master/Data%20Scrapping/Team_5_Part1_Report.pdf
#
# https://www.sec.gov/cgi-bin/viewer?action=view&cik=732712&accession_number=0001193125-10-041685&xbrl_type=v
#
# https://www.codeproject.com/Articles/1227268/Accessing-Financial-Reports-in-the-EDGAR-Database
#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all-next-and-find-next

# %%
cleaned_verizon_data
# Out:
#      Unnamed: 0  Unnamed: 0.1       fdate     cik  findexdate  form  \
# 0          2265          2265  1994-01-21  732712  1994-03-31   8-K
# 1          2266          2266  1994-02-01  732712  1994-03-31   8-K
# 2          2267          2267  1994-02-09  732712  1994-03-31   8-K
# 3          2268          2268  1994-02-14  732712  1994-03-31   8-K
# 4          2269          2269  1994-02-24  732712  1994-03-31   8-K
# 5          2270          2270  1994-03-23  732712  1994-03-31   8-K
# 6          2271          2271  1994-03-31  732712  1994-03-31  10-K
# 7          2272          2272  1994-04-22  732712  1994-06-30   8-K
# 8          2273          2273  1994-05-13  732712  1994-06-30  10-Q
# 9          2274          2274  1994-07-21  732712  1994-07-21   8-K
# 10         2275          2275  1994-08-15  732712  1994-08-15  10-Q
# 11         2276          2276  1994-10-21  732712  1994-10-21   8-K
# 12         2277          2277  1994-11-14  732712  1994-11-14  10-Q
# 13         2278          2278  1995-01-25  732712  1995-01-25   8-K
# 14         2279          2279  1995-04-25  732712  1995-04-25   8-K
# 15         2280          2280  1995-05-12  732712  1995-05-12  10-Q
# 16         2281          2281  1995-07-24  732712  1995-07-24   8-K
# 17         2282          2282  1995-08-11  732712  1995-08-11  10-Q
# 18         2283          2283  1995-10-23  732712  1995-10-23   8-K
# 19         2284          2284  1995-11-13  732712  1995-11-13  10-Q
# 20         2285          2285  1996-01-23  732712  1996-01-23   8-K
# 21         2286          2286  1996-01-24  732712  1996-01-24   8-K
# 22         2287          2287  1996-04-18  732712  1996-04-18   8-K
# 23         2288          2288  1996-04-23  732712  1996-04-23   8-K
# 24         2289          2289  1996-05-09  732712  1996-05-09  10-Q
# 25         2290          2290  1996-07-03  732712  1996-07-03   8-K
# 26         2291          2291  1996-07-18  732712  1996-07-18   8-K
# 27         2292          2292  1996-08-09  732712  1996-08-09  10-Q
# 28         2293          2293  1996-10-21  732712  1996-10-21   8-K
# 29         2294          2294  1996-11-08  732712  1996-11-08  10-Q
# ..          ...           ...         ...     ...         ...   ...
# 495        2760          2760  2017-06-15  732712  2017-06-15   8-K
# 496        2761          2761  2017-07-27  732712  2017-07-27   8-K
# 513  0000732712-18-000009.txt : 20180223%%000073271...
# 514  0001193125-18-073362.txt : 20180307%%000119312...
# 515  0000732712-18-000015.txt : 20180424%%000073271...
# 516  0000732712-18-000022.txt : 20180501%%000073271...
# 517  0000732712-18-000024.txt : 20180501%%000073271...
# 518  0001193125-18-155421.txt : 20180508%%000119312...
# 519  0001193125-18-187324.txt : 20180608%%000119312...
# 520  0001193125-18-189002.txt : 20180611%%000119312...
# 521  0001193125-18-194627.txt : 20180615%%000119312...
# 522  0000732712-18-000040.txt : 20180724%%000073271...
# 523  0000732712-18-000044.txt : 20180731%%000073271...
# 524  0001193125-18-268028.txt : 20180906%%000119312...
#
#                     file_name  \
# 0    verizoncom_sec_files.csv
# 1    verizoncom_sec_files.csv
# 2    verizoncom_sec_files.csv
# 3    verizoncom_sec_files.csv
# 4    verizoncom_sec_files.csv
# 5    verizoncom_sec_files.csv
# 6    verizoncom_sec_files.csv
# 7    verizoncom_sec_files.csv
# 8    verizoncom_sec_files.csv
# 9    verizoncom_sec_files.csv
# 10   verizoncom_sec_files.csv
# 11   verizoncom_sec_files.csv
# 12   verizoncom_sec_files.csv
# 13   verizoncom_sec_files.csv
# 14   verizoncom_sec_files.csv
# 15   verizoncom_sec_files.csv
# 16   verizoncom_sec_files.csv
# 17   verizoncom_sec_files.csv
# 18   verizoncom_sec_files.csv
# 19   verizoncom_sec_files.csv
# 20   verizoncom_sec_files.csv
# 21   verizoncom_sec_files.csv
# 22   verizoncom_sec_files.csv
# 23   verizoncom_sec_files.csv
# 24   verizoncom_sec_files.csv
# 25   verizoncom_sec_files.csv
# 26   verizoncom_sec_files.csv
# 27   verizoncom_sec_files.csv
# 28   verizoncom_sec_files.csv
# 29   verizoncom_sec_files.csv
# ..                        ...
# 495  verizoncom_sec_files.csv
# 496  verizoncom_sec_files.csv
# 497  verizoncom_sec_files.csv
# 498  verizoncom_sec_files.csv
# 499  verizoncom_sec_files.csv
# 500  verizoncom_sec_files.csv
# 501  verizoncom_sec_files.csv
# 502  verizoncom_sec_files.csv
# 503  verizoncom_sec_files.csv
# 504  verizoncom_sec_files.csv
# 505  verizoncom_sec_files.csv
# 506  verizoncom_sec_files.csv
# 507  verizoncom_sec_files.csv
# 508  verizoncom_sec_files.csv
# 509  verizoncom_sec_files.csv
# 510  verizoncom_sec_files.csv
# 511  verizoncom_sec_files.csv
# 512  verizoncom_sec_files.csv
# 513  verizoncom_sec_files.csv
# 514  verizoncom_sec_files.csv
# 515  verizoncom_sec_files.csv
# 516  verizoncom_sec_files.csv
# 517  verizoncom_sec_files.csv
# 518  verizoncom_sec_files.csv
# 519  verizoncom_sec_files.csv
# 520  verizoncom_sec_files.csv
# 521  verizoncom_sec_files.csv
# 522  verizoncom_sec_files.csv
# 523  verizoncom_sec_files.csv
# 524  verizoncom_sec_files.csv
#
#                                         only_eng_words  \
# 0    BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 1    BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 2    BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 3    BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 4    BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 5    BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 6    BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 7    BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 8    BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 9    BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 10   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 11   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 12   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 13   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 14   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 15   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 16   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 17   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 18   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 19   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 20   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 21   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 22   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 23   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 24   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 25   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 26   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 27   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 28   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# 29   BEGIN PRIVACY ENHANCED MESSAGE Type CLEAR Orig...
# ..                                                 ...
# 495  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 496  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 497  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 498  ACCESSION NUMBER SUBMISSION TYPE Q PUBLIC DOCU...
# 499  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 500  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 501  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 502  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 503  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 504  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 505  ACCESSION NUMBER SUBMISSION TYPE Q PUBLIC DOCU...
# 506  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 507  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 508  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 509  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 510  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 511  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 512  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 513  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 514  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 515  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 516  ACCESSION NUMBER SUBMISSION TYPE Q PUBLIC DOCU...
# 517  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 518  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 519  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 520  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 521  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 522  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
# 523  ACCESSION NUMBER SUBMISSION TYPE Q PUBLIC DOCU...
# 524  ACCESSION NUMBER SUBMISSION TYPE K PUBLIC DOCU...
#
#                                           evy_gram_1_3
# 0    ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 1    ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 2    ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 3    ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 4    ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 5    ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 6    ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 7    ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 8    ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 9    ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 10   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 11   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 12   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 13   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 14   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 15   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 16   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 17   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 18   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 19   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 20   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 21   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 22   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 23   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 24   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 25   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 26   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 27   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 28   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# 29   ['BEGIN', 'PRIVACY', 'ENHANCED', 'MESSAGE', 'T...
# ..                                                 ...
# 495  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 496  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 497  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 498  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 499  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 500  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 501  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 502  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 503  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 504  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 505  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 506  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 507  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 508  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 509  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 510  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 511  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 512  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 513  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 514  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 515  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 516  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 517  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 518  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 519  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 520  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 521  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 522  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 523  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
# 524  ['ACCESSION', 'NUMBER', 'SUBMISSION', 'TYPE', ...
#
# [525 rows x 14 columns]

# %%
print(cleaned_verizon_data[cleaned_verizon_data['form']=='8-K']['sec_full_path'][0])
print(cleaned_verizon_data[cleaned_verizon_data['form']=='8-K']['sec_full_path'][1])
print(cleaned_verizon_data[cleaned_verizon_data['form']=='8-K']['sec_full_path'][2])
# Out:
# https://www.sec.gov/Archives/edgar/data/732712/0000950133-94-000018.txt
# https://www.sec.gov/Archives/edgar/data/732712/0000950172-94-000010.txt
# https://www.sec.gov/Archives/edgar/data/732712/0000893220-94-000061.txt

# %%
cleaned_verizon_data[['file_name','form']]\
.groupby(['form'])\
.agg(['count'])\
.reset_index()
# Out:
#    form file_name
#             count
# 0  10-K        21
# 1  10-Q        74
# 2   8-K       430

# %% [markdown]
# ## Explore a 10K

# %%
test_html = 'https://www.sec.gov/Archives/edgar/data/732712/0000950109-94-000587.txt'
test_file = request.urlopen(test_html).read().decode('utf8')

# %%
#r = re.compile(r'\table\b | \bCAPTION\b', flags=re.I | re.X)
#r = re.compile(r'\table\b\bCAPTION\b', flags=re.I | re.X)
#r = re.compile(r'\<table\>\s*\<caption\>')

# %%
soup = BeautifulSoup(test_file,'html.parser')
table = soup.find_all('table')

# %%
table[3]
# Out:
# <table>
# <caption>
#                                                                                           Held
#         Name                  Age                      Office                             Since
#         ----                  ---                      ------                             -----
# <s> <c> <c> <c>
# Raymond W. Smith...........   56  Chairman of the Board and Chief Executive Officer        1989
# James G. Cullen............   51  President                                                1993
# William O. Albertini.......   50  Vice President and Chief Financial Officer               1991
# Joseph T. Ambrozy..........   54  Vice President - Strategic Planning                      1992
# Lawrence T. Babbio, Jr.....   49  Chairman, President and Chief Executive Officer,         1991
#                                         Bell Atlantic Enterprises International, Inc.
# P. Alan Bulliner...........   50  Vice President - Corporate Secretary and Counsel         1992
# Barbara L. Connor..........   43  Vice President - Finance and Controller and Treasurer    1993
# Charles W. Crist...........   50  Vice President - Human Resources                         1990
# John F. Gamba..............   55  Group President, Network Technologies and Systems,       1993
#                                         Bell Atlantic Network Services, Inc.
# Bruce S. Gordon............   48  Group President - Consumer and Small Business Services,  1993
#                                         Bell Atlantic Network Services, Inc.
# Stuart C. Johnson..........   51  Group President, Large Business and Information          1993
#                                         Services, Bell Atlantic Network Services, Inc.
# Brian J. Kelly.............   59  Group President, Network Operations,                     1993
#                                         Bell Atlantic Network Services, Inc.
# Robert M. Valentini........   50  President and Chief Executive Officer, Bell Atlantic -   1988
#                                         Pennsylvania, Inc.
# James R. Young.............   42  Vice President and General Counsel                       1992
# </c></c></c></s></caption></table>

# %% [markdown]
# ## Explore a 8-K

# %%
test_html = 'https://www.sec.gov/Archives/edgar/data/732712/0000950133-94-000018.txt'
test_file = request.urlopen(test_html).read().decode('utf8')

# %%
soup = BeautifulSoup(test_file,'html.parser')
## find all tables
table = soup.find_all('table')
## search the text
Item_text = soup.findAll(text=re.compile("Item "))

# %%
table
# Out:
# [<table>
#  <s> <c>
#  Date of Report:                              January 20, 1994
#
#  Exact name of registrant
#  as specified in its charter:                 BELL ATLANTIC CORPORATION
#
#  Commission File No.:                         1-8606
#
#  State of Incorporation:                      Delaware
#
#  IRS Employer Identification No.:             23-2259884
#
#  Address of principal
#  executive offices:                           1717 Arch Street
#                                               Philadelphia, Pennsylvania
#  Zip Code                                     19103
#
#  Registrant's telephone number,
#  including area code:                         (215) 963-6000
#
#  Former name or former address,
#  if changed since last report:                N/A
#  </c></s></table>]

# %%
Item_text
# Out:
# ['   2\n\n\n\n\nItem 5.  Other Events.\n\n     Bell Atlantic Corporation (the "Company") today said that rumors that the\nCompany intends to cut its dividend are totally false. The Company does not\nintend to cut its dividend as a result of its pending merger with\nTeleCommunications, Inc. ("TCI") and Liberty Media Corporation ("Liberty").\n\n     The Company also confirmed that negotiations on that transaction are\nproceeding satisfactorily. The proposed merger is an exceedingly complex\ntransaction, and, as in any negotiation, various elements may be modified. It\nis the Company\'s intention that the final financial terms of the transaction\nwill not differ significantly from the Letter of Intent executed by the\nCompany, TCI and Liberty on October 12, 1993.\n']

# %%
re.search('(?<=Item )\d', Item_text_id[0])
# Out:
# <_sre.SRE_Match object; span=(10, 11), match='5'>

# %% [markdown]
# ## Another 8-K with two Items

# %%
test_html = 'https://www.sec.gov/Archives/edgar/data/732712/0000893220-94-000061.txt'
test_file = request.urlopen(test_html).read().decode('utf8')

# %%
soup = BeautifulSoup(test_file,'html.parser')
## find all tables
table = soup.find_all('table')
## search the text
Item_text = soup.findAll(text=re.compile("Item "))

# %%
Item_text[1]
# Out:
# '   4\nItem 7. Financial Statements and Exhibits.\n\n(c)  Exhibits.\n\nThe exhibit identified below is filed as an exhibit hereto.\n\nExhibit 99:\n\nUnaudited condensed consolidated statements of income, unaudited other selected\ndata and unaudited selected operating statistics for the three months and year\nended December 31, 1993 and 1992.\n'

# %%
[re.search('(?<=Item ).*', i).group(0) for i in Item_text]
# Out:
# ['5. Other Events.', '7. Financial Statements and Exhibits.']

# %%
soup = BeautifulSoup(html)
table = soup.find("table", attrs={"class":"details"})

# The first tr contains the field names.
headings = [th.get_text() for th in table.find("tr").find_all("th")]

datasets = []
for row in table.find_all("tr")[1:]:
    dataset = zip(headings, (td.get_text() for td in row.find_all("td")))
    datasets.append(dataset)

# %%
##8-k
test_html = 'https://www.sec.gov/Archives/edgar/data/732712/0000950109-94-000587.txt'
test_file = request.urlopen(test_html).read().decode('utf8')
